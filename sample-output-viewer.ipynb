# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/")
# !ls
# Out:
# MyDrive

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
#  2019-07-20-12-46-51-622_1563607011622_XXXPA5802X_ITRV.zip
#  2019-07-21-11-31-41-300_1563688901300_XXXPA5802X_Acknowledgement.zip
# 'assignment 3 (1).pdf'
# 'assignment 3.pdf'
# 'assignment 4.pdf'
# 'biswajit mishra.gsheet'
# 'Colab Notebooks'/
# 'Etoos Lectures'/
# 'Flower Generating DC GAN'/
# 'Format for learning outcome - V.gsheet'
# 'Getting started.pdf'
#  IMG_20201108_195227.jpg
# 'IMG20210204161655_00 (1).jpg'
#  IMG20210204161655_00.jpg
#  IMG20210204162117_00.jpg
# 'IMG20210204162404_00 (1).jpg'
#  IMG20210204162404_00.jpg
#  IMG_20220115_142418.jpg
# 'PLANNER-3( Biswajit ).gsheet'
# 'Untitled document.gdoc'
# 'Untitled drawing.gdraw'
# 'VII MATHS  J R PANDA (1).xlsx'
# 'VII MATHS  J R PANDA.gdoc'
# 'VII MATHS  J R PANDA.gsheet'
# 'VII MATHS  J R PANDA.pdf'
# 'VII MATHS  J R PANDA.xlsx'
# 'V Rajeev Kumar Ajad.gsheet'

# %%
cd "Flower Generating DC GAN"
# Out:
# /content/drive/MyDrive/Flower Generating DC GAN

# %%
import dataset as ds
import model as mdl
import tensorflow as tf
from tqdm import tqdm

# %%
import matplotlib.pyplot as plt

# %%
data = ds.Dataset().load_data()

# %%
model = mdl.Model()

# %%
model.learning_rate = 0.0001
model.beta_1 = 0.05

# %%
model.GAN()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1600)              161600
#
#  reshape (Reshape)           (None, 4, 4, 100)         0
#
#  conv2d_transpose (Conv2DTra  (None, 8, 8, 50)         125050
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 25)       125025
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 64, 64, 3)        7503
#  ranspose)
#
# =================================================================
# Total params: 419,178
# Trainable params: 419,178
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 200)       9800
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 100)       500100
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 9)         22509
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense_1 (Dense)             (None, 1)                 2305
#
# =================================================================
# Total params: 534,714
# Trainable params: 534,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.dataset = data

# %%
model.epochs = 12

# %%
for i in tqdm(range(500)):
    model.training_steps()
# Out:
# 100%|██████████| 500/500 [1:02:40<00:00,  7.52s/it]

# %%
for i in range(25):
    plt.subplot(5, 5, i+ 1)
    plt.imshow(model.gan.layers[0](tf.random.normal(shape=[1, 100]))[0])

# %%
plt.imshow(model.gan.layers[0](tf.random.normal(shape=[1, 100]))[0])
